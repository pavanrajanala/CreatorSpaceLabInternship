# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrajanala/CreatorSpaceLabInternship/blob/main/BankLoanAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be32b182-3181-43c9-ac63-3aeada441a33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be32b182-3181-43c9-ac63-3aeada441a33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Bank_loan.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
print("Rows and columns : ",df.shape)
print("\n Column names: ",df.columns)
print("\n Data Set Info")
df.info()
# Out:
# Rows and columns :  (614, 13)
#
#  Column names:  Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
#
#  Data Set Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
df['Loan_Status'].value_counts().plot(kind='bar')
plt.title('Loan Status')
plt.xlabel('Staeus')
plt.ylabel('Count')
plt.show()

# %%
avg_income = np.mean(df['ApplicantIncome'])
print("avg_income : ",avg_income)
median_income = np.median(df['ApplicantIncome'])
print("median_income : ",median_income)
std_income = np.std(df['ApplicantIncome'])
print("std_income : ",std_income)
min_income = np.min(df['ApplicantIncome'])
print("min_income : ",min_income)
max_income = np.max(df['ApplicantIncome'])
print("max_income : ",max_income)
min_loan = np.min(df['LoanAmount'])
print("Min Loan : ",min_loan)
max_loan=np.max(df['LoanAmount'])
print("Max Laon : ",max_loan)
std_loan=np.std(df['LoanAmount'])
print("Std Loan : ",std_loan)
median_loan=np.median(df['LoanAmount'])
print("Median Loan : ",median_loan)
# Out:
# avg_income :  5403.459283387622
# median_income :  3812.5
# std_income :  6104.064856533888
# min_income :  150
# max_income :  81000
# Min Loan :  9.0
# Max Laon :  700.0
# Std Loan :  85.51500809120331
# Median Loan :  nan

# %%
p25 = np.percentile(df['ApplicantIncome'],25)
p50 = np.percentile(df['ApplicantIncome'],50)
p75 = np.percentile(df['ApplicantIncome'],75)

print(p25,p50,p75)
# Out:
# 2877.5 3812.5 5795.0

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']
np.mean(df['TotalIncome'])
# Out:
# np.float64(7024.705081414722)

# %%
plt.hist(df['ApplicantIncome'])

plt.title("Applicant Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")

plt.show()

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Total Stength")
plt.show()

# %%
df['Loan_Status'].value_counts().plot(kind='bar')
plt.title("Loan Status Distribution")
plt.xlabel("Loan Status")
plt.ylabel("Total Stength")
plt.show()

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
plt.hist(df['LoanAmount'])
plt.title("Loan Amount Distribution")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
plt.show()

# %%
area = df['Property_Area'].value_counts()

plt.pie(area,labels=area.index,autopct='%1.1f%%')

plt.title("Property Area Distribution")

plt.show()
